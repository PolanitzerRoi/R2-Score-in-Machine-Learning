# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
from sklearn import datasets
boston = datasets.load_boston()

# %%
X = boston.data
y = boston.target
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
linear_regression = LinearRegression()
linear_regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_mean = np.mean(y_test)
y_pred = linear_regression.predict(X_test)
y_true = y_test

# %%
from sklearn.metrics import r2_score
R2_SCORE = r2_score(y_true, y_pred)
print('Linear Regression R2 score": %.6f' % R2_SCORE)
# Out:
# Linear Regression R2 score": 0.726157

# %%
from IPython.display import Image
Image(filename='TSS ESS.png')

# %%
Image(filename='R2 SCORE.png')

# %%
RSS = np.sum( (y_true-y_pred)**2 )
ESS = np.sum( (y_pred-y_mean)**2 )
TSS = np.sum( (y_true-y_mean)**2 )

# %%
R2_SCORE1 = 1-RSS/TSS
print('Linear Regression R2 score": %.6f' % R2_SCORE1)
# Out:
# Linear Regression R2 score": 0.726157
